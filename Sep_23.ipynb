# %% [markdown]
# #### **Arguments**

# %%
def name():
    age=input()
    if age >=18:
        print()
    else:
        print ()

# %% [markdown]
# #### **Positional**

# %%
def student_grades(A, B, C):
    if A == 90:
        print("Grade A")
    if B == 80:
        print("Grade B")
    if C == 70:
        print("Grade C")

student_grades(90, 80, 70)
# Out:
# Grade A
# Grade B
# Grade C

# %% [markdown]
# #### **Keyword**

# %%
def student_name(girl_name="Ayesha", boy_name="Ali"):
    print(girl_name, boy_name)
student_name()
# Out:
# Ayesha Ali

# %% [markdown]
# #### **Default**

# %%
def address(house_no,street_no,city="Islamabad"):
    print("house_no=","street_no=","city=")
address(house_no=3,street_no=4)
# Out:
# house_no= street_no= city=

# %% [markdown]
# #### **Positional Argument**

# %%
def count_microbes(*args):
    """Takes any number of microbial species and prints a summary."""
    print("Number of microbial species found:", len(args))
    print("Species detected:")
    for species in args:
        print("-", species)

# Example call:
count_microbes("Lactobacillus", "Geotrichum candidum", "Bifidobacterium", "Saccharomyces")
# Out:
# Number of microbial species found: 4
# Species detected:
# - Lactobacillus
# - Geotrichum candidum
# - Bifidobacterium
# - Saccharomyces

# %%
def colony_count(*args):
    """Takes CFU/ml counts of different samples and gives total + average."""
    total = sum(args)
    avg = total / len(args)
    print("Total colonies counted:", total)
    print("Average colonies per sample:", avg)

# Example:
colony_count(120, 250, 300, 450)
# Out:
# Total colonies counted: 1120
# Average colonies per sample: 280.0

# %%
def antibiotic_sensitivity(*args):
    """List all antibiotics a strain is sensitive to."""
    print("Sensitive to the following antibiotics:")
    for drug in args:
        print("✔", drug)

# Example:
antibiotic_sensitivity("Amoxicillin", "Ciprofloxacin", "Erythromycin")
# Out:
# Sensitive to the following antibiotics:
# ✔ Amoxicillin
# ✔ Ciprofloxacin
# ✔ Erythromycin

# %%
def species_ph(*args):
    """Takes species name and its optimum pH in pairs."""
    print("Species and their optimum pH:")
    for i in range(0, len(args), 2):
        print(f"{args[i]}: optimum pH = {args[i+1]}")

# Example:
species_ph("Lactobacillus", 5.5, "Geotrichum candidum", 6.5, "Saccharomyces", 4.5)
# Out:
# Species and their optimum pH:
# Lactobacillus: optimum pH = 5.5
# Geotrichum candidum: optimum pH = 6.5
# Saccharomyces: optimum pH = 4.5

# %%
def sample_batch(*args):
    """Show the samples combined into one batch test."""
    print("Samples included in this batch test:")
    for sdfgh in args:
        print(sdfgh)

# Example call
sample_batch("Milk sample 1", "Yogurt sample 2", "Cheese sample 3")
# Out:
# Samples included in this batch test:
# Milk sample 1
# Yogurt sample 2
# Cheese sample 3

# %%
def growth_temps(*args):
    """Takes species and their temperatures in pairs and prints them."""
    print("Species and their optimum temperatures:")
    for i in range(0, len(args), 2):
        print(f"{args[i]} grows best at {args[i+1]}°C")

# Example call
growth_temps("Lactobacillus", 37, "Geotrichum candidum", 28, "Saccharomyces", 30)
# Out:
# Species and their optimum temperatures:
# Lactobacillus grows best at 37°C
# Geotrichum candidum grows best at 28°C
# Saccharomyces grows best at 30°C
