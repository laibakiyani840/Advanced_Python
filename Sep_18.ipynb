# %% [markdown]
# #### **Arithmetic Operator**

# %% [markdown]
# #### **Add**

# %%
a=56
b=22
c=a+b
print(c)
# Out:
# 78

# %% [markdown]
# #### **Subtract**

# %%
c=a-b
print(c)
# Out:
# 34

# %% [markdown]
# #### **Multiply**

# %%
c=a*b
print(c)
# Out:
# 1232

# %% [markdown]
# #### **Divide**

# %%
c=a/b
print(c)
# Out:
# 2.5454545454545454

# %% [markdown]
# #### **Power**

# %%
c=a**b
print(c)
# Out:
# 288493873028852398739253829029106548736

# %% [markdown]
# #### **Modules**

# %%
c=a%b
print(c)
# Out:
# 12

# %% [markdown]
# #### **Conditions**

# %%
a=8
if a>5:
    print(a)
# Out:
# 8

# %%
a=3
if a>5:
    print(a)              ## no output

# %%
a=3
if a>5:
    print(a)
else:
    print(a)
# Out:
# 3

# %%
a=3
if a>5:
    print("Greater")
else:
    print("Smaller")
# Out:
# Smaller

# %%
score = 50
if score>=90:
    print("Grade A")
elif score>=80:
    print("Grade B")
elif score>=70:
    print("Grade C")
elif score>=60:
    print("Grade D")
else:
    print("Grade E")
# Out:
# Grade E

# %%
score = 50
if score>=90:
    print("Grade A")
elif score>=80:
    print("Grade B")
elif score>=70:
    print("Grade C")
elif score>=60:
    print("Grade D")
else:
    print("Fail")
# Out:
# Fail

# %%
score = 60
if score>=90:
    print("Grade A")
elif score>=80:
    print("Grade B")
elif score>=70:
    print("Grade C")
elif score>=60:
    print("Grade D")
else:
    print("Fail")
# Out:
# Grade D

# %%
score = 77
if score>=90:
    print("Grade A")
elif score>=80:
    print("Grade B")
elif score>=70:
    print("Grade C")
elif score>=60:
    print("Grade D")
else:
    print("Fail")
# Out:
# Grade C

# %%
a=input("Enter your Marks")
a="5"
a=int(a)
print(a)
# Out:
# Enter your Marks 45
# 5

# %%
a=input("Enter your Marks")
# a="5"
score=int(a)
if score>=90:
    print("Grade A")
elif score>=80:
    print("Grade B")
elif score>=70:
    print("Grade C")
elif score>=60:
    print("Grade D")
else:
    print("Fail")
# Out:
# Enter your Marks 59
# Fail

# %%
a=input("Enter your Marks")
a="5"
a=int(a)
# Out:
# Enter your Marks 70

# %% [markdown]
# #### **Dictionary**

# %%
person = {
    "name":"Ali",
    "age":30,
    "city":"Isl" }
print(person)
# Out:
# {'name': 'Ali', 'age': 30, 'city': 'Isl'}

# %%
print((person)["age"])
# Out:
# 30
